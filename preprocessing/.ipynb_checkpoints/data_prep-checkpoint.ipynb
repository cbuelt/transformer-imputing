# %% [markdown]
# # Preparation and data loading

# %%
# Import packages
import sys
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn import preprocessing
import datetime
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import plotly.express as px
import plotly.graph_objects as go
import pickle

#Import custom modules
sys.path.append('../')
from utils.utils import *

# %%
#Load data
all_data=pd.read_csv("../data/all_data_2015-2020.csv", index_col=0)
#Create datetime index
all_data.index = pd.to_datetime(all_data.index)
#Extract years
years = all_data["Year"].unique()
#Extract countries
countries = all_data["Country"].unique()
#Extract features 
features = all_data.columns

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Replace NaNs
# Nans should be replaced for values where the country does not use the specific production unit
# Replace with 0, because 0 kWh is generated

# %% [markdown]
# Create Loop to replace NaNs for production types that do not exist in the specific country with 0

# %%
data_summed=all_data.groupby(["Country"]).sum()
data_missing_prep = data_summed.copy().drop("Year",axis=1)
data_nan=data_missing_prep[data_missing_prep==0].dropna(axis=1, how="all")

for country in countries:
    #Get and insert n/e for specific country
    columns = data_nan.loc[country][data_nan.loc[country]==0].index.to_list()
    all_data.loc[all_data["Country"]==country,columns] = "n/e"
    
#Special case for HU and Geothermal/Fossil Hard Coal, PT and Wind Offshore
all_data.loc[all_data["Country"] == "HU", "Geothermal"] = all_data.loc[all_data["Country"] == "HU", "Geothermal"].fillna(0)
all_data.loc[all_data["Country"] == "HU", "Fossil Hard coal"] = all_data.loc[all_data["Country"] == "HU", "Geothermal"].fillna(0)
all_data.loc[all_data["Country"] == "PT", "Wind Offshore"] = all_data.loc[all_data["Country"] == "PT", "Wind Offshore"].fillna(0)
    
#Save data so it can be used for analysis of missing values
all_data.to_csv("../data/all_data_processed.csv")
#Replace n/e
all_data.replace({"n/e":0}, inplace = True)

# %%
all_data.head()
# Out:
#                            Year Country  Day_ahead_price    Load  Biomass  \
# 2015-01-01 00:00:00+00:00  2015      AT            88.20  6017.0    304.0
# 2015-01-01 01:00:00+00:00  2015      AT            65.08  5751.0    304.0
# 2015-01-01 02:00:00+00:00  2015      AT            46.82  5407.0    304.0
# 2015-01-01 03:00:00+00:00  2015      AT            22.60  5285.0    304.0
# 2015-01-01 04:00:00+00:00  2015      AT            31.06  5280.0    304.0
#
#                            Fossil Gas  Fossil Hard coal  Fossil Oil  \
# 2015-01-01 00:00:00+00:00       926.0              14.0         0.0
# 2015-01-01 01:00:00+00:00       756.0              14.0         0.0
# 2015-01-01 02:00:00+00:00       735.0              14.0         0.0
# 2015-01-01 03:00:00+00:00       724.0              14.0         0.0
# 2015-01-01 04:00:00+00:00       724.0              14.0         0.0
#
#                            Geothermal  Hydro Pumped Storage  ...  Other  \
# 2015-01-01 00:00:00+00:00         0.0                   0.0  ...  212.0
# 2015-01-01 01:00:00+00:00         0.0                   0.0  ...  266.0
# 2015-01-01 02:00:00+00:00         0.0                   0.0  ...  199.0
# 2015-01-01 03:00:00+00:00         0.0                   0.0  ...  172.0
# 2015-01-01 04:00:00+00:00         0.0                   0.0  ...  273.0
#
#                            Other renewable  Solar  Waste  Wind Onshore  \
# 2015-01-01 00:00:00+00:00              0.0    0.0    0.0          74.0
# 2015-01-01 01:00:00+00:00              0.0    0.0    0.0          62.0
# 2015-01-01 02:00:00+00:00              0.0    0.0    0.0          67.0
# 2015-01-01 03:00:00+00:00              0.0    0.0    0.0          63.0
# 2015-01-01 04:00:00+00:00              0.0    0.0    0.0          61.0
#
#                            Fossil Brown coal/Lignite  Fossil Coal-derived gas  \
# 2015-01-01 00:00:00+00:00                        0.0                      0.0
# 2015-01-01 01:00:00+00:00                        0.0                      0.0
# 2015-01-01 02:00:00+00:00                        0.0                      0.0
# 2015-01-01 03:00:00+00:00                        0.0                      0.0
# 2015-01-01 04:00:00+00:00                        0.0                      0.0
#
#                            Nuclear  Wind Offshore  Fossil Peat
# 2015-01-01 00:00:00+00:00      0.0            0.0          0.0
# 2015-01-01 01:00:00+00:00      0.0            0.0          0.0
# 2015-01-01 02:00:00+00:00      0.0            0.0          0.0
# 2015-01-01 03:00:00+00:00      0.0            0.0          0.0
# 2015-01-01 04:00:00+00:00      0.0            0.0          0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Encoding year and country

# %%
# Year encoding
min_year=2015
all_data.loc[:,"Year"] = all_data.loc[:,"Year"] - min_year

# %%
#Country encoding
countries = all_data.loc[:,"Country"].unique()
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(countries)
all_data.loc[:,"Country"] = label_encoder.transform(all_data.loc[:,"Country"])

#Show list
country_codes = dict(zip(label_encoder.classes_,label_encoder.transform(label_encoder.classes_)))
country_codes
# Out:
# {'AT': 0,
#  'BE': 1,
#  'BG': 2,
#  'CH': 3,
#  'CZ': 4,
#  'DE-AT-LU': 5,
#  'DE-LU': 6,
#  'DK': 7,
#  'EE': 8,
#  'ES': 9,
#  'FI': 10,
#  'FR': 11,
#  'GB': 12,
#  'GR': 13,
#  'HR': 14,
#  'HU': 15,
#  'IE': 16,
#  'IT': 17,
#  'LT': 18,
#  'LV': 19,
#  'NL': 20,
#  'NO': 21,
#  'PL': 22,
#  'PT': 23,
#  'RO': 24,
#  'RS': 25,
#  'SE': 26,
#  'SI': 27,
#  'SK': 28}

# %% [markdown]
# ## Encoding Weekday and Hour

# %%
#Add weekday
all_data.insert(1,"Weekday",all_data.index.weekday)
#Add hour
all_data.insert(2,"Hour",all_data.index.hour)

# %% [markdown]
# ## Aggregate and rename features

# %%
#Other
other = ["Other", "Fossil Peat", "Other renewable", "Waste", "Fossil Oil", "Fossil Coal-derived gas", "Geothermal"]
all_data["Other"] = all_data[other].sum(axis=1, skipna = False)
all_data.drop(other[1:],axis=1, inplace=True)

#Hydro
hydro = ["Hydro Run-of-river and poundage", "Hydro Water Reservoir"]
all_data["Hydro"] = all_data[hydro].sum(axis=1, skipna = False)
all_data.drop(hydro, axis = 1, inplace = True)

# %%
all_data.isna().sum()/all_data.count()
# Out:
# Year                         0.000000
# Weekday                      0.000000
# Hour                         0.000000
# Country                      0.000000
# Day_ahead_price              0.021076
# Load                         0.001976
# Biomass                      0.031164
# Fossil Gas                   0.060797
# Fossil Hard coal             0.033901
# Hydro Pumped Storage         0.070817
# Other                        0.097240
# Solar                        0.074298
# Wind Onshore                 0.010289
# Fossil Brown coal/Lignite    0.006979
# Nuclear                      0.004488
# Wind Offshore                0.004648
# Hydro                        0.079947
# dtype: float64

# %%
#Rename
all_data.rename(columns = {"Fossil Brown coal/Lignite":"Lignite", "Solar":"PV",
                           "Fossil Hard coal": "Hard coal",
# 2020-12-31 23:00:00+00:00   1968.0            0.0   490.0
#
# [1429224 rows x 17 columns]

# %% [markdown]
# ## Normalize data

# %%
#Save year, weekday, hour and country since they do not neet to be normalized
columns_to_save = all_data.iloc[:,0:4]
#Save mean and sd
mean = all_data.mean()
sd = all_data.std()
#Normalize
all_data = (all_data-mean)/sd
#Reset columns from earlier
all_data.iloc[:,0:4] = columns_to_save
#Save normalization
save_norm = [mean, sd]
with open("../data/data_normalization.pkl", "wb") as stream:
    pickle.dump(save_norm,stream)

# %% [markdown]
# ## NaN encoding

# %%
df_nan = all_data.iloc[:,4:].copy()
df_nan[df_nan.isna()==False]=0
df_nan.fillna(1,inplace=True)
df_nan.columns = [col for col in df_nan.columns + "_nan"]

# %%
data_enc = pd.concat([all_data,df_nan],axis=1)

#Fill Nans
data_enc.fillna(0,inplace=True)

data_enc.head()
# Out:
#                            Year  Weekday  Hour  Country  Day_ahead_price  \
# 2015-01-01 00:00:00+00:00     0        3     0        0         0.822994
# 2015-01-01 01:00:00+00:00     0        3     1        0         0.318383
# 2015-01-01 02:00:00+00:00     0        3     2        0        -0.080154
# 2015-01-01 03:00:00+00:00     0        3     3        0        -0.608773
# 2015-01-01 04:00:00+00:00     0        3     4        0        -0.424127
#
#                                Load   Biomass  Fossil Gas  Hard coal  \
# 2015-01-01 00:00:00+00:00 -0.451792 -0.068995   -0.331468  -0.460221
# 2015-01-01 01:00:00+00:00 -0.468543 -0.068995   -0.381799  -0.460221
# 2015-01-01 02:00:00+00:00 -0.490205 -0.068995   -0.388016  -0.460221
# 2015-01-01 03:00:00+00:00 -0.497888 -0.068995   -0.391273  -0.460221
# 2015-01-01 04:00:00+00:00 -0.498202 -0.068995   -0.391273  -0.460221
#
#                            Pumped Storage  ...  Fossil Gas_nan  Hard coal_nan  \
# 2015-01-01 00:00:00+00:00       -0.359091  ...             0.0            0.0
# 2015-01-01 01:00:00+00:00       -0.359091  ...             0.0            0.0
# 2015-01-01 02:00:00+00:00       -0.359091  ...             0.0            0.0
# 2015-01-01 03:00:00+00:00       -0.359091  ...             0.0            0.0
# 2015-01-01 04:00:00+00:00       -0.359091  ...             0.0            0.0
#
#                            Pumped Storage_nan  Other_nan  PV_nan  \
# 2015-01-01 00:00:00+00:00                 0.0        0.0     0.0
# 2015-01-01 01:00:00+00:00                 0.0        0.0     0.0
# 2015-01-01 02:00:00+00:00                 0.0        0.0     0.0
# 2015-01-01 03:00:00+00:00                 0.0        0.0     0.0
# 2015-01-01 04:00:00+00:00                 0.0        0.0     0.0
#
#                            Wind Onshore_nan  Lignite_nan  Nuclear_nan  \
# 2015-01-01 00:00:00+00:00               0.0          0.0          0.0
# 2015-01-01 01:00:00+00:00               0.0          0.0          0.0
# 2015-01-01 02:00:00+00:00               0.0          0.0          0.0
# 2015-01-01 03:00:00+00:00               0.0          0.0          0.0
# 2015-01-01 04:00:00+00:00               0.0          0.0          0.0
#
#                            Wind Offshore_nan  Hydro_nan
# 2015-01-01 00:00:00+00:00                0.0        0.0
# 2015-01-01 01:00:00+00:00                0.0        0.0
# 2015-01-01 02:00:00+00:00                0.0        0.0
# 2015-01-01 03:00:00+00:00                0.0        0.0
# 2015-01-01 04:00:00+00:00                0.0        0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Positional encoding

# %%
#Hour encoding
data_enc[0] = np.sin(data_enc.index.hour * np.pi*2 /24)
data_enc[1] = np.cos(data_enc.index.hour * np.pi*2 /24)

#Week encoding
data_enc[2] = np.sin((data_enc.index.weekday*24+data_enc.index.hour) * np.pi*2 / (7*24))
data_enc[3] = np.cos((data_enc.index.weekday*24+data_enc.index.hour) * np.pi*2 / (7*24))

#Encoding normal year
data_enc[4] = np.sin((data_enc.index.dayofyear*24+data_enc.index.hour) * np.pi*2 / (365*24))
data_enc[5] = np.cos((data_enc.index.dayofyear*24+data_enc.index.hour) * np.pi*2 / (365*24))

#Encoding leap year
enc = data_enc.loc[data_enc["Year"].isin([1,5])].index
data_enc.loc[data_enc["Year"].isin([1,5]), 4] = np.sin(((enc.dayofyear-1) * 24 + enc.hour) * np.pi*2 / (366*24))
data_enc.loc[data_enc["Year"].isin([1,5]), 5] = np.cos(((enc.dayofyear-1) * 24 + enc.hour) * np.pi*2 / (366*24))

# %%
data_enc
# Out:
#                            Year  Weekday  Hour  Country  Day_ahead_price  \
# 2015-01-01 00:00:00+00:00     0        3     0        0         0.822994
# 2015-01-01 01:00:00+00:00     0        3     1        0         0.318383
# 2015-01-01 02:00:00+00:00     0        3     2        0        -0.080154
# 2015-01-01 03:00:00+00:00     0        3     3        0        -0.608773
# 2015-01-01 04:00:00+00:00     0        3     4        0        -0.424127
# ...                         ...      ...   ...      ...              ...
# 2020-12-31 19:00:00+00:00     5        3    19       28        -0.000708
# 2020-12-31 20:00:00+00:00     5        3    20       28        -0.047634
# 2020-12-31 21:00:00+00:00     5        3    21       28        -0.060511
# 2020-12-31 22:00:00+00:00     5        3    22       28        -0.112020
# 2020-12-31 23:00:00+00:00     5        3    23       28        -0.108091
#
#                                Load   Biomass  Fossil Gas  Hard coal  \
# 2015-01-01 00:00:00+00:00 -0.451792 -0.068995   -0.331468  -0.460221
# 2015-01-01 01:00:00+00:00 -0.468543 -0.068995   -0.381799  -0.460221
# 2015-01-01 02:00:00+00:00 -0.490205 -0.068995   -0.388016  -0.460221
# 2015-01-01 03:00:00+00:00 -0.497888 -0.068995   -0.391273  -0.460221
# 2015-01-01 04:00:00+00:00 -0.498202 -0.068995   -0.391273  -0.460221
# ...                             ...       ...         ...        ...
# 2020-12-31 19:00:00+00:00 -0.640834 -0.285617   -0.421176  -0.465570
# 2020-12-31 20:00:00+00:00 -0.647068 -0.284528   -0.427689  -0.465570
# 2020-12-31 21:00:00+00:00 -0.650972 -0.283439   -0.467066  -0.465570
# 2020-12-31 22:00:00+00:00 -0.653995 -0.282351   -0.536345  -0.465570
# 2020-12-31 23:00:00+00:00 -0.657458 -0.282351   -0.537529  -0.465570
#
#                            Pumped Storage  ...  Lignite_nan  Nuclear_nan  \
# 2015-01-01 00:00:00+00:00       -0.359091  ...          0.0          0.0
# 2015-01-01 01:00:00+00:00       -0.359091  ...          0.0          0.0
# 2015-01-01 02:00:00+00:00       -0.359091  ...          0.0          0.0
# 2015-01-01 03:00:00+00:00       -0.359091  ...          0.0          0.0
# 2015-01-01 04:00:00+00:00       -0.359091  ...          0.0          0.0
# ...                                   ...  ...          ...          ...
# 2020-12-31 19:00:00+00:00       -0.342546  ...          0.0          0.0
# 2020-12-31 20:00:00+00:00        0.000000  ...          0.0          0.0
# 2020-12-31 21:00:00+00:00        0.000000  ...          0.0          0.0
# 2020-12-31 22:00:00+00:00        0.000000  ...          0.0          0.0
# 2020-12-31 23:00:00+00:00        0.000000  ...          0.0          0.0
#
#                            Wind Offshore_nan  Hydro_nan         0         1  \
# 2015-01-01 00:00:00+00:00                0.0        0.0  0.000000  1.000000
# 2015-01-01 01:00:00+00:00                0.0        0.0  0.258819  0.965926
# 2015-01-01 02:00:00+00:00                0.0        0.0  0.500000  0.866025
# 2015-01-01 03:00:00+00:00                0.0        0.0  0.707107  0.707107
# 2015-01-01 04:00:00+00:00                0.0        0.0  0.866025  0.500000
# ...                                      ...        ...       ...       ...
# 2020-12-31 19:00:00+00:00                0.0        0.0 -0.965926  0.258819
# 2020-12-31 20:00:00+00:00                0.0        0.0 -0.866025  0.500000
# 2020-12-31 21:00:00+00:00                0.0        0.0 -0.707107  0.707107
# 2020-12-31 22:00:00+00:00                0.0        0.0 -0.500000  0.866025
# 2020-12-31 23:00:00+00:00                0.0        0.0 -0.258819  0.965926
#
#                                   2         3         4         5
# 2015-01-01 00:00:00+00:00  0.433884 -0.900969  0.017213  0.999852
# 2015-01-01 01:00:00+00:00  0.399892 -0.916562  0.017931  0.999839
# 2015-01-01 02:00:00+00:00  0.365341 -0.930874  0.018648  0.999826
# 2015-01-01 03:00:00+00:00  0.330279 -0.943883  0.019365  0.999812
# 2015-01-01 04:00:00+00:00  0.294755 -0.955573  0.020082  0.999798
# ...                             ...       ...       ...       ...
# 2020-12-31 19:00:00+00:00 -0.258819 -0.965926 -0.003576  0.999994
# 2020-12-31 20:00:00+00:00 -0.294755 -0.955573 -0.002861  0.999996
# 2020-12-31 21:00:00+00:00 -0.330279 -0.943883 -0.002146  0.999998
# 2020-12-31 22:00:00+00:00 -0.365341 -0.930874 -0.001431  0.999999
# 2020-12-31 23:00:00+00:00 -0.399892 -0.916562 -0.000715  1.000000
#
# [1429224 rows x 36 columns]

# %%
data_enc.iloc[0:360,-5:].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Create train/test split

# %%
# Add month to data
data_enc.insert(4,"Month",data_enc.index.month-1)

# %%
data_enc
# Out:
#                            Year  Weekday  Hour  Country  Month  \
# 2015-01-01 00:00:00+00:00     0        3     0        0      0
# 2015-01-01 01:00:00+00:00     0        3     1        0      0
# 2015-01-01 02:00:00+00:00     0        3     2        0      0
# 2015-01-01 03:00:00+00:00     0        3     3        0      0
# 2015-01-01 04:00:00+00:00     0        3     4        0      0
# ...                         ...      ...   ...      ...    ...
# 2020-12-31 19:00:00+00:00     5        3    19       28     11
# 2020-12-31 20:00:00+00:00     5        3    20       28     11
# 2020-12-31 21:00:00+00:00     5        3    21       28     11
# 2020-12-31 22:00:00+00:00     5        3    22       28     11
# 2020-12-31 23:00:00+00:00     5        3    23       28     11
#
#                            Day_ahead_price      Load   Biomass  Fossil Gas  \
# 2015-01-01 00:00:00+00:00         0.822994 -0.451792 -0.068995   -0.331468
# 2020-12-31 22:00:00+00:00 -0.365341 -0.930874 -0.001431  0.999999
# 2020-12-31 23:00:00+00:00 -0.399892 -0.916562 -0.000715  1.000000
#
# [1429224 rows x 37 columns]

# %%
split_ratio = 0.15

test_df =data_enc.iloc[:,0:4].copy()
test_df["Month"] = test_df.index.month
test_df.drop(["Hour","Weekday"],axis=1,inplace=True)
test_df.drop_duplicates(inplace=True)

split = int(np.round(split_ratio*len(test_df)))

sample_df = test_df.sample(split, random_state = 13)

# %% [markdown]
# Extract train/test set from data

# %%
#Function to create rolling window
def create_rolling_window(data, window = 7):
    n_days = int(data.shape[0]/24)
    input_data = []
    for day in range(n_days):
        if day >= 0 and day < n_days-(window-1):
            input_data.append(data[(day*24):(day+window)*24])
    input_data = np.array(input_data)
    return(input_data)

# %%
#Reset index
data_enc.reset_index(inplace=True)

# %%
# An dieser Stelle schon testdaten transformieren und zusätzlich index speichern um trainingsdaten zu transformieren
index_list = list()
first = True

for x in range(len(sample_df)):
    sample = sample_df.iloc[x,]
    sample_data = data_enc[(data_enc["Year"]==sample["Year"])&(data_enc["Month"]+1==sample["Month"])&(data_enc["Country"]==sample["Country"])]
    index = sample_data.index
    index_list.extend(index)
    if first==True:
        testing_data_reshaped = create_rolling_window(np.array(sample_data),window=5)
        first=False
    else:
        testing_data_reshaped = np.append(testing_data_reshaped,create_rolling_window(np.array(sample_data),window=5),axis=0)

# %%
#Index extrahieren
testing_index = testing_data_reshaped[:,:,0]
testing_data_reshaped = testing_data_reshaped[:,:,1:]

# %%
#Index aus Trainingsdaten löschen
training_data = data_enc.iloc[:,1:].copy()
training_data["Test_data"]=0
training_data.loc[training_data.index.isin(index_list),"Test_data"] = 1

# %% [markdown]
# Funktionen um Daten zu transformieren

# %%
def create_rolling_window_train(data, window = 7):
    n_days = int(data.shape[0]/24)
    input_data = []
    for day in range(n_days):
        if day >= 0 and day < n_days-(window-1):
            data_subset = data[(day*24):(day+window)*24]
            if 1 not in data_subset[:,-1]:
                input_data.append(data_subset[:,:-1])

    input_data = np.array(input_data)
    return(input_data)

# %%
#Conplete function to transform data
def transform_data(data, countries, window=7):
    #Variable to check for the first loop iteration
    first = True
    
    for country in countries:
        df = data[data["Country"]==country]
        data_array = np.array(df)
        data_array = create_rolling_window_train(data_array,window)

        #Check if its the first iteration
        if first ==True:
            data_reshaped = data_array
            first=False        
        else:
            data_reshaped = np.append(data_reshaped,data_array,axis=0)
            
    return data_reshaped

# %%
training_data_reshaped = transform_data(data = training_data, countries = training_data["Country"].unique(),window=5)

# %% [markdown]
# # Save data

# %% [markdown]
# Create feature information

# %%
#Need to change
countries = np.array(list(country_codes.values()))
years = data_enc["Year"].unique()
feature_names = all_data.columns[4:]
no_features = len(feature_names)

feature_information = [countries, years, feature_names, no_features]

# %%
#Save reshaped training and testing data
np.save("../data/training_data_reshaped",training_data_reshaped.astype("float32"))
np.save("../data/testing_data_reshaped",testing_data_reshaped.astype("float32"))

#Save testing index
np.save("../data/testing_data_index",testing_index)

#Save information
with open("../data/data_information.pkl", "wb") as p:
    pickle.dump(feature_information, p)
